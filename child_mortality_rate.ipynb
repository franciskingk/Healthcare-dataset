# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/home/francis/group_project_ds_GDP/datasets_project/CME_DF_2020a.csv")
df.head(10)
# Out:
# /home/francis/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (5,8,18,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Geographic area                Indicator    Sex  \
# 0     Afghanistan  Neonatal mortality rate  Total
# 1     Afghanistan  Neonatal mortality rate  Total
# 2     Afghanistan  Neonatal mortality rate  Total
# 3     Afghanistan  Neonatal mortality rate  Total
# 4     Afghanistan  Neonatal mortality rate  Total
# 5     Afghanistan  Neonatal mortality rate  Total
# 6     Afghanistan  Neonatal mortality rate  Total
# 7     Afghanistan  Neonatal mortality rate  Total
# 8     Afghanistan  Neonatal mortality rate  Total
# 9     Afghanistan  Neonatal mortality rate  Total
#
#                                        Series Name Series Year Regional group  \
# ...

# %%
# Filter the file to only Kenya
Kenya=(df['Geographic area'] == 'Kenya')
Kenya
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 475247    False
# 475248    False
# 475249    False
# 475250    False
# 475251    False
# Name: Geographic area, Length: 475252, dtype: bool

# %%
#drop all other rows except kenyan ones

new_df = df[df['Geographic area'] == 'Kenya']
new_df
# Out:
#        Geographic area                Indicator    Sex  \
# 202609           Kenya  Neonatal mortality rate  Total
# 202610           Kenya  Neonatal mortality rate  Total
# 202611           Kenya  Neonatal mortality rate  Total
# 202612           Kenya  Neonatal mortality rate  Total
# 202613           Kenya  Neonatal mortality rate  Total
# ...                ...                      ...    ...
# 205239           Kenya        Deaths age 5 to 9  Total
# 205240           Kenya        Deaths age 5 to 9  Total
# 205241           Kenya        Deaths age 5 to 9  Total
# 205242           Kenya        Deaths age 5 to 9  Total
# 205243           Kenya        Deaths age 5 to 9  Total
#
#                                         Series Name Series Year  \
# 202609  Demographic and Health Survey 2014 (Direct)        2014
# 202610  Demographic and Health Survey 2014 (Direct)        2014
# 202611  Demographic and Health Survey 2014 (Direct)        2014
# ...

# %%
#drop all null columns namely CONNECTION	CATEGORY Age Group of Women	Time Since First Birth	DEFINITION LOWER_BOUND	UPPER_BOUND	STATUS YEAR_TO_ACHIEVE	Model Used DEATH_CATEGORY
# Regional group COUNTRY_NOTES
nonull_df=new_df.drop(['CONNECTION', 'CATEGORY', 'Age Group of Women', 'Time Since First Birth', 'DEFINITION', 'LOWER_BOUND', 'UPPER_BOUND', 'STATUS', 'YEAR_TO_ACHIEVE', 'Model Used', 'DEATH_CATEGORY', 'Regional group', 'COUNTRY_NOTES'], axis =1 )
nonull_df
# Out:
#        Geographic area                Indicator    Sex  \
# 202609           Kenya  Neonatal mortality rate  Total
# 202610           Kenya  Neonatal mortality rate  Total
# 202611           Kenya  Neonatal mortality rate  Total
# 202612           Kenya  Neonatal mortality rate  Total
# 202613           Kenya  Neonatal mortality rate  Total
# ...                ...                      ...    ...
# 205239           Kenya        Deaths age 5 to 9  Total
# 205240           Kenya        Deaths age 5 to 9  Total
# 205241           Kenya        Deaths age 5 to 9  Total
# 205242           Kenya        Deaths age 5 to 9  Total
# 205243           Kenya        Deaths age 5 to 9  Total
#
#                                         Series Name Series Year TIME_PERIOD  \
# 202609  Demographic and Health Survey 2014 (Direct)        2014     1991-06
# 202610  Demographic and Health Survey 2014 (Direct)        2014     1996-06
# ...

# %%
# drop columns that are not in use for the research namely OBS_VALUE Observation Status	Series Category	Series Type	REF_DATE Series Method
Kenyan_df = nonull_df.drop(['OBS_VALUE', 'Observation Status', 'Series Category', 'Series Type', 'REF_DATE', 'Series Method'], axis=1)
Kenyan_df
# Out:
#        Geographic area                Indicator    Sex  \
# 202609           Kenya  Neonatal mortality rate  Total
# 202610           Kenya  Neonatal mortality rate  Total
# 202611           Kenya  Neonatal mortality rate  Total
# 202612           Kenya  Neonatal mortality rate  Total
# 202613           Kenya  Neonatal mortality rate  Total
# ...                ...                      ...    ...
# 205239           Kenya        Deaths age 5 to 9  Total
# 205240           Kenya        Deaths age 5 to 9  Total
# 205241           Kenya        Deaths age 5 to 9  Total
# 205242           Kenya        Deaths age 5 to 9  Total
# 205243           Kenya        Deaths age 5 to 9  Total
#
#                                         Series Name Series Year TIME_PERIOD  \
# 202609  Demographic and Health Survey 2014 (Direct)        2014     1991-06
# 202610  Demographic and Health Survey 2014 (Direct)        2014     1996-06
# ...

# %%
kenyan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2635 entries, 202609 to 205243
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Geographic area     2635 non-null   object
#  1   Indicator           2635 non-null   object
#  2   Sex                 2635 non-null   object
#  3   Series Name         2635 non-null   object
#  4   Series Year         2635 non-null   object
#  5   TIME_PERIOD         2635 non-null   object
#  6   OBS_VALUE           2635 non-null   float64
#  7   Observation Status  2635 non-null   object
#  8   Unit of measure     2635 non-null   object
#  9   Series Category     791 non-null    object
#  10  Series Type         755 non-null    object
#  11  STD_ERR             589 non-null    float64
#  12  REF_DATE            2635 non-null   float64
#  13  INTERVAL            2392 non-null   float64
#  14  Series Method       791 non-null    object
# ...
